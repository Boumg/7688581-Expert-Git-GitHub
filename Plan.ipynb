# %% [markdown]
# <a href="https://colab.research.google.com/github/Boumg/7688581-Expert-Git-GitHub/blob/main/Plan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# /*
#               # 2. Qu'est ce que l'agilité
#
#               Edwards Deming
#
#               ## Une approche Collaborative
#
#               ## Une approche Emergent
#
#               ## L'apprentissage Continue
#
#               ## L'Amélioration Continue
#
#
#
#               # 3. Scrum, le Framework
#
#               ## Le Frameworks SCRUM n'est pas unique
#
#               ## Srcum Team & ses rôles
#
#               ## les artefacts
#
#               ## Les évènements Scrum
# */
#
# # 1 Artisant du codeCraftManShip
#
# # 2 Comprendre les enjeux du code
#
#   ## C'est quoi le bon code ?
#
#   ## TD Demander l'avis des éléves à partir des exemples simples
#
#   ## Donnée une défintion
#
#      - contrats
#      - simplicité/sécurité/efficiant
#
#   ## Dette technique
#
#   ## Conséquences de la dette technique
#
#   ##  Régles simples de détection du mauvais code
#
# # 3. les méthodes utilsiés pour le bon code
#
#   ## Tests des contrats
#
#   ## TDD
#
#   ## Cata
#
#   ## BDD/TDD
#
#   ## Arcitecture & Conception Emergente
#
#   ## Extrem Programming
#
# # 4. le pourqoui des outils
#
#   ### activités
#
#  - gestion de version et de configuration
#  - work flow
#  - Idempotence
#  - Délégation
#  - Découpage, Orthogonalité
#  - Mélange des paradigmes de programation, notament desc
#
#   ### As code
#   ### Automatisation
#
#
#   ## DevOps
#   A regarder  Demo  (je  n'ai pas cherché car pb chez  mes projets (clause de sécurité)
#
# # 5. Posture & Pratiques
#
#   ## Imaginer une solution adaptée
#
#   ## Apporter de la valeur régulièrement
#
#   ## S'adapter au chagements
#
#
# 120 planches => 6H
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ##
